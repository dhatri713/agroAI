# %%
import pandas as pd
import numpy as np
import glob

# %%
import os

# %%
folder_path = "/home/dhatri/Capstone Project/KCC data/batch1/*.csv"
files = glob.glob(folder_path)

# %%
final_dfs = []

# %%
dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)

# %%
df = pd.concat(dfs, ignore_index=True)

# %%
df
# Out:
#       StateName   DistrictName BlockName  Season       Sector  Category  Crop  \
# 0     TELANGANA          MEDAK         0  KHARIF  AGRICULTURE         0  1576
# 1     TELANGANA     RANGAREDDY         0  KHARIF  AGRICULTURE         0  1653
# 2     TELANGANA       ADILABAD         0  KHARIF         9999         0  9999
# 3     TELANGANA       ADILABAD         0  KHARIF         9999         0  9999
# 4     TELANGANA     KARIMNAGAR         0  KHARIF  AGRICULTURE         0  1037
# ...         ...            ...       ...     ...          ...       ...   ...
# 8117  TELANGANA      NIZAMABAD         0    RABI         9999         0  9999
# 8118  TELANGANA      NIZAMABAD         0    RABI         9999         0  9999
# 8119  TELANGANA  MAHABOOBNAGAR         0    RABI  AGRICULTURE         0  1037
# 8120  TELANGANA     RANGAREDDY         0    RABI         9999         0  9999
# 8121  TELANGANA     RANGAREDDY         0    RABI         9999         0  9999
#
# ...

# %%
df["Crop"].unique()
# Out:
# array(['1576', '1653', '9999', '1037', 'Citrus',
#        'Peas (field peas/ garden peas/matar)', '1268', '1137', '1324',
#        '1075', '1280', 'Pig', 'Sunflower (suryamukhi)', 'Oil palm',
#        'Sunnhemp (Patua)', 'Tobacco', 'Tomato', '2051', 'Ber', 'Lemon',
#        'Sapota', '1279', 'Banana', 'Watermelon', 'Carrot',
#        'Cotton (Kapas)', 'Teak', 'Oats ', 'Onion', 'Sheep', 'Rabbit',
#        'Saffron', '1287', 'Guava', '1808', 'Horse', '1976', '1296',
#        '1275', 'Ash Gourd (Petha)', 'Curry Leaf', 'Bovine(Cow,Buffalo)',
#        'Groundnut (pea nut/mung phalli)', '964', 'Cabbage', 'Others',
#        'Neem', 'Black Gram (urd bean)', 'Wheat',
#        'Pigeon pea (red gram/arhar/tur)', 'Snake Gourd', 'Mustard',
#        'Turmeric', 'Mushroom', 'Chrysanthemum', 'Rose', '2113', '2103',
#        '2763', '2108', '2047', 'Coconut', 'Coriander',
#        'Castor (Rehri, Rendi, Arandi) ', 'Radish', '1233', 'Pear',
#        'Gladiolus', '2114', 'Soybean (bhat)', '1282',
# ...

# %%
crops = ["Cotton (Kapas)", "Groundnut (pea nut/mung phalli)", "1137", 'Black Gram (urd bean)', 'Pigeon pea (red gram/arhar/tur)', 'Green Gram (Moong Bean/ Moong)']
df = df[df['Crop'].isin(crops)]
df
# Out:
#       StateName DistrictName BlockName  Season       Sector  Category  Crop  \
# 13    TELANGANA        MEDAK         0  KHARIF  AGRICULTURE         0  1137
# 15    TELANGANA    NIZAMABAD         0  KHARIF  AGRICULTURE         0  1137
# 33    TELANGANA    NIZAMABAD         0  KHARIF  AGRICULTURE         0  1137
# 37    TELANGANA   RANGAREDDY         0  KHARIF  AGRICULTURE         0  1137
# 45    TELANGANA     NALGONDA         0  KHARIF  AGRICULTURE         0  1137
# ...         ...          ...       ...     ...          ...       ...   ...
# 8052  TELANGANA     NALGONDA         0    RABI  AGRICULTURE         0  1137
# 8078  TELANGANA     ADILABAD         0    RABI  AGRICULTURE         0  1137
# 8079  TELANGANA   RANGAREDDY         0    RABI  AGRICULTURE         0  1137
# 8082  TELANGANA   RANGAREDDY         0    RABI  AGRICULTURE         0  1137
# 8106  TELANGANA     ADILABAD         0    RABI  AGRICULTURE         0  1137
#
# ...

# %%
df.columns
# Out:
# Index(['StateName', 'DistrictName', 'BlockName', 'Season', 'Sector',
#        'Category', 'Crop', 'QueryType', 'QueryText', 'KccAns', 'CreatedOn',
#        'year', 'month', 'Unnamed: 0'],
#       dtype='object')

# %%
cols = ['Crop', 'QueryType', 'QueryText', 'KccAns']
df = df[cols]
df['QueryType'].unique()
# Out:
# array(['3', '21', '2', 'Fertilizer Use and Availability', '6', '5',
#        'Weather', '1', '29', '10', '0', '22', '18',
#        '\tWater Management\t', 'Soil Testing', 0, nan, '12', '26'],
#       dtype=object)

# %%
cats = ['3', '10', '21', '22', 'Fertilizer Use and Availability']
df = df[df['QueryType'].isin(cats)]
final_dfs.append(df)
df
# Out:
#       Crop QueryType                                       QueryText  \
# 13    1137         3          ASKED ABOUT THE CONTROL OF BPH IN RICE
# 15    1137         3  ASKED ABOUT THE CONTROL OF LEAF FOLDER IN RICE
# 33    1137         3        ASKED ABOUT THE CONTROL OF HISPA IN RICE
# 37    1137         3        ASKED ABOUT THE CONTROL OF BLAST IN RICE
# 45    1137        21        ASKED ABOUT THE CONTROL OF WEEDS IN RICE
# ...    ...       ...                                             ...
# 8027  1137         3              ASKED ABOUT CONTROL OF BPH IN RICE
# 8036  1137         3            ASSKED ABOUT CONTROL RICE STEM BORER
# 8041  1137         3  ASKED ABOUT CONTROL FOR RICE STEM BORER DAMAGE
# 8049  1137         3              ASKED ABOUT CONTROL OF BPH IN RICE
# 8079  1137         3  ASKED ABOUT CONTROL FOR RICE STEM BORER DAMAGE
#
#                                              KccAns
# 13           RECOMMENDED TO SPRAY ACEPHATE 1.5GM/LT
# ...

# %%
folder_path = "/home/dhatri/Capstone Project/KCC data/batch2/*.csv"
files = glob.glob(folder_path)
dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)
df = pd.concat(dfs, ignore_index=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   StateName     8763 non-null   object
#  1   DistrictName  8763 non-null   object
#  2   BlockName     8763 non-null   object
#  3   Season        6577 non-null   object
#  4   Sector        8763 non-null   object
#  5   Category      8763 non-null   int64
#  6   Crop          8763 non-null   object
#  7   QueryType     8760 non-null   object
#  8   QueryText     8763 non-null   object
#  9   KccAns        8276 non-null   object
#  10  CreatedOn     8763 non-null   object
#  11  year          8761 non-null   object
#  12  month         8763 non-null   object
#  13  Unnamed: 13   3 non-null      float64
#  14  Unnamed: 14   3 non-null      float64
# dtypes: float64(2), int64(1), object(12)
# memory usage: 1.0+ MB

# %%
df["Crop"].unique()
# Out:
# array(['9999', 'Tobacco', '1296', '1268', '1037', '1136', '2051', 'Ber',
#        'Citrus', '1137', 'Cotton (Kapas)', 'Coriander', '964', '1653',
#        '1280', '1279', 'Groundnut (pea nut/mung phalli)', 'Others',
#        'Onion', 'Carrot', '1075', 'Lilliums', '1818', 'Sunnhemp (Patua)',
#        'Black Gram (urd bean)', 'Sunflower (suryamukhi)',
#        'Castor (Rehri, Rendi, Arandi) ', 'Watermelon',
#        'Pigeon pea (red gram/arhar/tur)', 'Banana',
#        'Green Gram (Moong Bean/ Moong)', '2014', 'Saffron', '1282',
#        '1066', 'Potato', 'Beekeeping', 'Turmeric', '2113', '2108',
#        'Bovine(Cow,Buffalo)', 'Guar', '1275', '2827', '2047',
#        'Betel Vine', 'Babool', 'Celery', '1808', 'Teak', '1324',
#        'Marigold', 'Tomato', '1285', 'Sapota', 'Coconut', 'Sheep', '2100',
#        'Anthurium', 'Garlic', 'Beet Root (Garden Beet/Stock Beet)',
#        'Ash Gourd (Petha)', '1064', 'Mushroom', 'Cabbage', 'Goat', '1266',
# ...

# %%
crops = ["Cotton (Kapas)", "Groundnut (pea nut/mung phalli)", "1137", 'Black Gram (urd bean)', 'Pigeon pea (red gram/arhar/tur)', 'Green Gram (Moong Bean/ Moong)', 'Chillies']
df = df[df['Crop'].isin(crops)]
df
# Out:
#            StateName   DistrictName BlockName  Season       Sector  Category  \
# 130   ANDHRA PRADESH         GUNTUR         0   JAYAD  AGRICULTURE         0
# 186   ANDHRA PRADESH  WEST GODAVARI         0   JAYAD  AGRICULTURE         0
# 237   ANDHRA PRADESH        KURNOOL         0   JAYAD  AGRICULTURE         0
# 250   ANDHRA PRADESH        KRISHNA         0   JAYAD  AGRICULTURE         0
# 310   ANDHRA PRADESH       ANANTPUR      0        NaN  AGRICULTURE         0
# ...              ...            ...       ...     ...          ...       ...
# 8741       TELANGANA          MEDAK         0  KHARIF  AGRICULTURE         0
# 8747       TELANGANA     KARIMNAGAR         0  KHARIF  AGRICULTURE         0
# 8756       TELANGANA          MEDAK         0  KHARIF  AGRICULTURE         0
# 8758       TELANGANA       ADILABAD         0  KHARIF  AGRICULTURE         0
# 8760       TELANGANA       WARANGAL         0  KHARIF  AGRICULTURE         0
#
# ...

# %%
cols = ['Crop', 'QueryType', 'QueryText', 'KccAns']
df = df[cols]
df['QueryType'].unique()
# Out:
# array(['3', '2', '6', 'Agriculture Mechanization', '26', '18', '12',
#        'Fertilizer Use and Availability', '5', '22', '29', '1',
#        'Cultural Practices', 2, 3, '9', 'Weather', '21', '17', '0', '27',
#        'Market Information', '19', '99', '10', '76', '15', '75',
#        '\tWater Management\t', '\tPlant Protection\t', 'Soil Testing',
#        '11', '87', '\tField Preparation\t', '91'], dtype=object)

# %%
cats = ['3', '10', '21', '22', 'Fertilizer Use and Availability', '76', '29', '\tPlant Protection\t']
df = df[df['QueryType'].isin(cats)]
df
# Out:
#                                  Crop                        QueryType  \
# 130                              1137                                3
# 186                    Cotton (Kapas)                                3
# 316   Groundnut (pea nut/mung phalli)                                3
# 364                    Cotton (Kapas)  Fertilizer Use and Availability
# 370   Groundnut (pea nut/mung phalli)                                3
# ...                               ...                              ...
# 8724                             1137                               22
# 8733                   Cotton (Kapas)                                3
# 8739                   Cotton (Kapas)                                3
# 8756  Pigeon pea (red gram/arhar/tur)                                3
# 8758                   Cotton (Kapas)                                3
#
#                                               QueryText  \
# 130              ASKED ABOUT CONTROL OF RICE STEM BORER
# ...

# %%
folder_path = "/home/dhatri/Capstone Project/KCC data/batch3/*.csv"
files = glob.glob(folder_path)
dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)
    
df = pd.concat(dfs, ignore_index=True)

# %%
df["Crop"].unique()
# Out:
# array(['Cotton (Kapas)', 'Coriander', 'Groundnut (pea nut/mung phalli)',
#        '1075', '1137', 'Tomato', 'Others', '1280', 'Dolichos Bean',
#        '7905', 'Pigeon pea (red gram/arhar/tur)', 'Saffron', 'Banana',
#        'Sunflower (suryamukhi)', 'Castor (Rehri, Rendi, Arandi) ', '1279',
#        'Marigold', '1268', 'Cluster Bean', '2108', 'Turmeric', '2114',
#        'Curry Leaf', 'Onion', 'Greater Yam',
#        'Peas (field peas/ garden peas/matar)', 'Ridge Gourd', '2825',
#        'Mango', '1282', 'Green Gram (Moong Bean/ Moong)', '2103', '7520',
#        'Plum', 'Rose', '1325', '964', '2113', 'Citrus', '1576',
#        'Drum Stick', 'Black Gram (urd bean)', 'Guava', '8042', 'Cabbage',
#        '1037', 'Colocasia (Arvi, Arbi)', 'Soybean (bhat)', 'Carrot',
#        'Watermelon', '1266', 'Zentedeschia', 'African Sarson', '8101',
#        '1808', 'Bovine(Cow,Buffalo)', 'FingerMillet  (Ragi/Mandika)',
#        'Vanilla', 'Beekeeping', 'Poplar', 'Pig', 'Coconut', '1324',
# ...

# %%
crops = ["Cotton (Kapas)", "Groundnut (pea nut/mung phalli)", "1137", 'Black Gram (urd bean)', 'Pigeon pea (red gram/arhar/tur)', 'Green Gram (Moong Bean/ Moong)', 'Chillies']
df = df[df['Crop'].isin(crops)]
df
# Out:
#             StateName   DistrictName     BlockName Season       Sector  \
# 0      ANDHRA PRADESH        KRISHNA          0       NaN  AGRICULTURE
# 2      ANDHRA PRADESH       ANANTPUR    MADAKASIRA    NaN  AGRICULTURE
# 4      ANDHRA PRADESH         GUNTUR          0       NaN  AGRICULTURE
# 5      ANDHRA PRADESH  WEST GODAVARI          0       NaN  AGRICULTURE
# 7      ANDHRA PRADESH        KURNOOL  BETHAMCHERLA    NaN  AGRICULTURE
# ...               ...            ...           ...    ...          ...
# 25857  ANDHRA PRADESH         GUNTUR          IPUR    NaN  AGRICULTURE
# 25859  ANDHRA PRADESH       ANANTPUR    KALYANDRUG    NaN  AGRICULTURE
# 25860  ANDHRA PRADESH         GUNTUR          0       NaN  AGRICULTURE
# 25862  ANDHRA PRADESH  WEST GODAVARI    NALLAJERLA    NaN  AGRICULTURE
# 25863  ANDHRA PRADESH         GUNTUR        PONNUR    NaN  AGRICULTURE
#
#           Category                             Crop QueryType  \
# ...

# %%
cols = ['Crop', 'QueryType', 'QueryText', 'KccAns']
df = df[cols]
df['QueryType'].unique()
# Out:
# array(['0', '20', '3', '29', '22', 'Fertilizer Use and Availability',
#        '26', '21', '2', '5', '6', '27', '\tWater Management\t',
#        '\tField Preparation\t', '18', '19', 'Weather', '91',
#        '\tPlant Protection\t', '15', '1', '12', 'Cultural Practices',
#        'Agriculture Mechanization', '9', 'Soil Testing', '99', '87', '10',
#        '102', '11', '17'], dtype=object)

# %%
df.to_csv('test.csv')

# %%
cats = ['3', '10', '21', '22', 'Fertilizer Use and Availability', '\tPlant Protection\t', '76', '29']
df = df[df['QueryType'].isin(cats)]
final_dfs.append(df)

# %%
folder_path = "/home/dhatri/Capstone Project/KCC data/batch4/*.csv"
files = glob.glob(folder_path)
dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)
    
df = pd.concat(dfs, ignore_index=True)


df["Crop"].unique()
# Out:
# array(['Tomato', 'Green Gram (Moong Bean/ Moong)', 'Cotton (Kapas)',
#        'Groundnut (pea nut/mung phalli)', 'Bottle Gourd ', 'Paddy (Dhan)',
#        'Rose', 'Others', 'Maize (Makka)', 'Dolichos Bean', 'Teak',
#        'Beans ', 'Coconut', 'Pigeon pea (red gram/arhar/tur)',
#        'POULTRY  FARM ', 'Chillies', '2825', 'Sugarcane (Noble Cane)',
#        '7212', 'Coriander', 'Turmeric', 'Onion', 'Brinjal',
#        'Amaranthus/Grain Amaranthus', 'Mango',
#        'Pearl Millet (Bajra/Bulrush Millet/Spiked Millet)', 'Guar',
#        'Marigold', 'Cluster Bean', 'Black Gram (urd bean)',
#        'Bhindi(Okra/Ladysfinger)', 'Custard Apple', 'Grape', 'Cumin',
#        'Oil palm', 'Soybean (bhat)', 'Sunflower (suryamukhi)',
#        'Chinar Tree', '7207', 'Citrus',
#        'Bengal Gram (Gram/Chick Pea/Kabuli/Chana)', 'Bitter Gourd',
#        'Ridge Gourd', 'Senji', '1266', 'Goat', 'Ginger', 'Snake Gourd',
#        'Sheep', 'Jasmine', 'Jack Fruit',
# ...

# %%
crops = ["Cotton (Kapas)", "Groundnut (pea nut/mung phalli)", "1137", 'Black Gram (urd bean)', 'Pigeon pea (red gram/arhar/tur)', 'Green Gram (Moong Bean/ Moong)', 'Chillies']
df = df[df['Crop'].isin(crops)]
df
# Out:
#              StateName DistrictName      BlockName Season        Sector  \
# 1       ANDHRA PRADESH       GUNTUR    ROMPICHERLA    NaN   AGRICULTURE
# 2       ANDHRA PRADESH       GUNTUR   SATTENAPALLE    NaN   AGRICULTURE
# 3       ANDHRA PRADESH     ANANTPUR     KALYANDRUG    NaN   AGRICULTURE
# 4       ANDHRA PRADESH      KURNOOL         KALLUR    NaN   AGRICULTURE
# 5       ANDHRA PRADESH      KURNOOL  BANAGANAPALLE    NaN   AGRICULTURE
# ...                ...          ...            ...    ...           ...
# 102566  ANDHRA PRADESH       GUNTUR      KAREMPUDI    NaN   AGRICULTURE
# 102569  ANDHRA PRADESH     ANANTPUR         PAMIDI    NaN  HORTICULTURE
# 102575  ANDHRA PRADESH     ANANTPUR     AMARAPURAM    NaN  HORTICULTURE
# 102576  ANDHRA PRADESH         0              0       NaN   AGRICULTURE
# 102582  ANDHRA PRADESH       GUNTUR         KOLLUR    NaN  HORTICULTURE
#
#            Category                             Crop             QueryType  \
# ...

# %%
cols = ['Crop', 'QueryType', 'QueryText', 'KccAns']
df = df[cols]
df['QueryType'].unique()
# Out:
# array(['\tPlant Protection\t', 'Cultural Practices', '0', 'Weather',
#        'Fertilizer Use and Availability', 'Seeds', 'Nutrient Management',
#        'Market Information', 'Agriculture Mechanization',
#        'Crop Insurance', 'Soil Testing', 'Seeds and Planting Material',
#        '\tField Preparation\t', 'Training and Exposure Visits',
#        'Government Schemes', 'Varieties', 'Sowing Time and Weather',
#        '\tWater Management\t', 'Weed Management', 'Nursery Management',
#        'Bio-Pesticides and Bio-Fertilizers',
#        'Water Management, Micro Irrigation', 'Beekeeping',
#        'Field Preparation', '21', '19', '3', '22', '1', '18', '2', '5',
#        '29', '26', '20', '6', '9', '10', '12', '75', '27', '8', '76',
#        '11', '100', 'Spices and Condiment Crops', 'Storage', '78', '99',
#        '102', 'Post Harvest Preservation', 'Credit', '87', 'Landscaping',
#        '95', 'Power, Roads etc.'], dtype=object)

# %%
df.to_csv('test.csv')

# %%
cats = ['3', '10', '21', '22', 'Fertilizer Use and Availability', '\tPlant Protection\t', '76', '29', 'Weed Management', 'Bio-Pesticides and Bio-Fertilizers', 'Beekeeping']
df = df[df['QueryType'].isin(cats)]
final_dfs.append(df)
df
# Out:
#                                    Crop                        QueryType  \
# 1        Green Gram (Moong Bean/ Moong)             \tPlant Protection\t
# 3       Groundnut (pea nut/mung phalli)             \tPlant Protection\t
# 43                       Cotton (Kapas)             \tPlant Protection\t
# 81                             Chillies             \tPlant Protection\t
# 107     Groundnut (pea nut/mung phalli)  Fertilizer Use and Availability
# ...                                 ...                              ...
# 102319                         Chillies             \tPlant Protection\t
# 102488                   Cotton (Kapas)             \tPlant Protection\t
# 102558                         Chillies             \tPlant Protection\t
# 102576                   Cotton (Kapas)             \tPlant Protection\t
# 102582                         Chillies             \tPlant Protection\t
#
#                            QueryText  \
# 1       asked about bacterial blight
# ...

# %%
folder_path = "/home/dhatri/Capstone Project/KCC data/batch5/*.csv"
files = glob.glob(folder_path)
dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)
    
df = pd.concat(dfs, ignore_index=True)


df["Crop"].unique()
# Out:
# array(['Sorghum (Jowar/Great Millet)', 'Chillies', 'Others',
#        'Paddy (Dhan)', 'Onion', 'Spinach (Palak)',
#        'Black Gram (urd bean)', 'Groundnut (pea nut/mung phalli)',
#        'Sesame (Gingelly/Til)/Sesamum', 'Tomato', 'Maize (Makka)',
#        'Bengal Gram (Gram/Chick Pea/Kabuli/Chana)',
#        'Bhindi(Okra/Ladysfinger)', 'Pigeon pea (red gram/arhar/tur)',
#        'Melon', 'Cotton (Kapas)', 'Green Gram (Moong Bean/ Moong)',
#        'Castor (Rehri, Rendi, Arandi) ', 'Banana', 'Mango', 'Ridge Gourd',
#        'Brinjal', 'Papaya', 'Grape', 'Beans ', 'Citrus', 'Cucumber',
#        'Italian Millet (Thenai/Navane/Foxtail Millet/Kang)', 'Cabbage',
#        'Watermelon', 'Sheep', 'POULTRY  FARM ', 'Tobacco', 'Drum Stick',
#        'Coriander', 'Rabbit', 'Bottle Gourd ', 'Coconut', 'Oil palm',
#        'Turmeric', 'Cowpea (Vegetable)', 'Chrysanthemum', 'Lemon', 'Pig',
#        'Jamun', 'Bitter Gourd', 'Pomegranate', 'French Bean',
# ...

# %%
crops = ["Cotton (Kapas)", "Groundnut (pea nut/mung phalli)", "1137", 'Black Gram (urd bean)', 'Pigeon pea (red gram/arhar/tur)', 'Green Gram (Moong Bean/ Moong)', 'Chillies', 'Paddy (Dhan)']
df = df[df['Crop'].isin(crops)]
df
# Out:
#              StateName   DistrictName      BlockName Season        Sector  \
# 0       ANDHRA PRADESH       CHITTOOR       GUDIPALA   RABI  HORTICULTURE
# 2       ANDHRA PRADESH        KRISHNA  CHANDARLAPADU    NaN   AGRICULTURE
# 9       ANDHRA PRADESH         GUNTUR      ATCHEMPET    NaN  HORTICULTURE
# 11      ANDHRA PRADESH        NELLORE       MUTHUKUR    NaN  HORTICULTURE
# 13      ANDHRA PRADESH        NELLORE       CHEJERLA    NaN   AGRICULTURE
# ...                ...            ...            ...    ...           ...
# 202239  ANDHRA PRADESH        NELLORE          OZILI    NaN   AGRICULTURE
# 202249  ANDHRA PRADESH  EAST GODAVARI    RAJANAGARAM    NaN   AGRICULTURE
# 202250  ANDHRA PRADESH  EAST GODAVARI    KOTANANDURU    NaN   AGRICULTURE
# 202251  ANDHRA PRADESH         GUNTUR       GURAZALA   RABI  HORTICULTURE
# 202254  ANDHRA PRADESH        NELLORE          KOVUR    NaN  HORTICULTURE
#
#           Category                   Crop                        QueryType  \
# ...

# %%
cols = ['Crop', 'QueryType', 'QueryText', 'KccAns']
df = df[cols]
df['QueryType'].unique()
# Out:
# array(['Fertilizer Use and Availability', '\tPlant Protection\t',
#        'Nutrient Management', 'Weed Management', 'Seeds',
#        'Sowing Time and Weather', 'Varieties', 'Market Information',
#        'Cultural Practices', 'Storage', 'Weather',
#        '\tField Preparation\t', 'Seeds and Planting Material',
#        'Organic Farming', 'Bio-Pesticides and Bio-Fertilizers',
#        'Landscaping', '\tWater Management\t', 'Credit',
#        'Training and Exposure Visits', 'Crop Insurance',
#        'Agriculture Mechanization', 'Medicinal and Aromatic Plants',
#        'Nursery Management', 'Soil Testing', 'Government Schemes',
#        'Water Management, Micro Irrigation', 'Field Preparation',
#        'Post Harvest Preservation',
#        'Vegetative Propagation and Tissue Culture', 'Cold Storage',
#        'Old/Senile Orchard Rejuvenation', 'Spices and Condiment Crops',
#        'Power, Roads etc.'], dtype=object)

# %%
df.to_csv('test.csv')

# %%
cats = ['3', '10', '21', '22', 'Fertilizer Use and Availability', '\tPlant Protection\t', '76', '29', 'Weed Management', 'Bio-Pesticides and Bio-Fertilizers', 'Beekeeping']
df = df[df['QueryType'].isin(cats)]
final_dfs.append(df)

# %%
folder_path = "/home/dhatri/Capstone Project/KCC data/batch6/*.csv"
files = glob.glob(folder_path)
dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)
df = pd.concat(dfs, ignore_index=True)


df["Crop"].unique()
# Out:
# array(['Chillies', 'Others', 'Black Gram (urd bean)', 'Tomato',
#        'Maize (Makka)', 'Tobacco', 'Paddy (Dhan)',
#        'Bengal Gram (Gram/Chick Pea/Kabuli/Chana)', 'Beans ',
#        'Bhindi(Okra/Ladysfinger)', 'Green Gram (Moong Bean/ Moong)',
#        'Mango', 'Pigeon pea (red gram/arhar/tur)', 'Onion',
#        'Groundnut (pea nut/mung phalli)', 'Kodo Millet (Kodara/Varagu)',
#        'Banana', 'Citrus', 'Sorghum (Jowar/Great Millet)',
#        'Bovine(Cow,Buffalo)', 'Orange', 'Cotton (Kapas)',
#        'Sesame (Gingelly/Til)/Sesamum', 'Watermelon',
#        'Sunflower (suryamukhi)', 'Dolichos Bean', 'Chapan Kaddu',
#        'Leafy Vegetable', 'French Bean', 'Carrot', 'Brinjal', 'Goat',
#        'Coconut', 'Sugarcane (Noble Cane)', 'Ginger', 'Rose',
#        'Ash Gourd (Petha)', 'Garlic', 'Bitter Gourd', 'Mosambi',
#        'Cucumber', 'Ridge Gourd', 'Cabbage', 'Musk Melon', 'Drum Stick',
#        'Pearl Millet (Bajra/Bulrush Millet/Spiked Millet)', 'Jamun',
# ...

# %%
crops = ["Cotton (Kapas)", "Groundnut (pea nut/mung phalli)", "1137", 'Black Gram (urd bean)', 'Pigeon pea (red gram/arhar/tur)', 'Green Gram (Moong Bean/ Moong)', 'Chillies', 'Paddy (Dhan)']
df = df[df['Crop'].isin(crops)]
df
# Out:
#              StateName   DistrictName      BlockName Season        Sector  \
# 0       ANDHRA PRADESH       CHITTOOR       GUDIPALA   RABI  HORTICULTURE
# 2       ANDHRA PRADESH        KRISHNA  CHANDARLAPADU    NaN   AGRICULTURE
# 9       ANDHRA PRADESH         GUNTUR      ATCHEMPET    NaN  HORTICULTURE
# 11      ANDHRA PRADESH        NELLORE       MUTHUKUR    NaN  HORTICULTURE
# 13      ANDHRA PRADESH        NELLORE       CHEJERLA    NaN   AGRICULTURE
# ...                ...            ...            ...    ...           ...
# 202239  ANDHRA PRADESH        NELLORE          OZILI    NaN   AGRICULTURE
# 202249  ANDHRA PRADESH  EAST GODAVARI    RAJANAGARAM    NaN   AGRICULTURE
# 202250  ANDHRA PRADESH  EAST GODAVARI    KOTANANDURU    NaN   AGRICULTURE
# 202251  ANDHRA PRADESH         GUNTUR       GURAZALA   RABI  HORTICULTURE
# 202254  ANDHRA PRADESH        NELLORE          KOVUR    NaN  HORTICULTURE
#
#           Category                   Crop                        QueryType  \
# ...

# %%
cols = ['Crop', 'QueryType', 'QueryText', 'KccAns']
df = df[cols]
df['QueryType'].unique()
# Out:
# array(['Fertilizer Use and Availability', '\tPlant Protection\t',
#        'Nutrient Management', 'Weed Management', 'Seeds',
#        'Sowing Time and Weather', 'Varieties', 'Market Information',
#        'Cultural Practices', 'Storage', 'Weather',
#        '\tField Preparation\t', 'Seeds and Planting Material',
#        'Organic Farming', 'Bio-Pesticides and Bio-Fertilizers',
#        'Landscaping', '\tWater Management\t', 'Credit',
#        'Training and Exposure Visits', 'Crop Insurance',
#        'Agriculture Mechanization', 'Medicinal and Aromatic Plants',
#        'Nursery Management', 'Soil Testing', 'Government Schemes',
#        'Water Management, Micro Irrigation', 'Field Preparation',
#        'Post Harvest Preservation',
#        'Vegetative Propagation and Tissue Culture', 'Cold Storage',
#        'Old/Senile Orchard Rejuvenation', 'Spices and Condiment Crops',
#        'Power, Roads etc.'], dtype=object)

# %%
df.to_csv('test.csv')

# %%
cats = ['3', '10', '21', '22', 'Fertilizer Use and Availability', '\tPlant Protection\t', '76', '29', 'Weed Management', 'Bio-Pesticides and Bio-Fertilizers', 'Beekeeping']
df = df[df['QueryType'].isin(cats)]
final_dfs.append(df)

# %%
folder_path = "/home/dhatri/Capstone Project/KCC data/batch7/*.csv"
files = glob.glob(folder_path)
dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)
    
df = pd.concat(dfs, ignore_index=True)


df["Crop"].unique()
# Out:
# array(['Others', 'Onion', 'Maize (Makka)', 'Cotton (Kapas)', 'Marigold',
#        'Bitter Gourd', 'Mango', 'Orange', 'Dolichos Bean', 'Tomato',
#        'Groundnut (pea nut/mung phalli)', 'Ash Gourd (Petha)', 'Brinjal',
#        'Paddy (Dhan)', 'Sugarcane (Noble Cane)', 'Chillies', 'Citrus',
#        'Mustard', 'Ridge Gourd', 'Tulsi', 'Potato',
#        'Sesame (Gingelly/Til)/Sesamum', 'Beans ',
#        'Pigeon pea (red gram/arhar/tur)', 'Black Gram (urd bean)',
#        'Coconut', 'Bottle Gourd ', 'Green Gram (Moong Bean/ Moong)',
#        'Sunflower (suryamukhi)', 'Papaya', 'Bhindi(Okra/Ladysfinger)',
#        'Banana', 'Cabbage', 'Aonla', 'Ber', 'Carrot',
#        'Castor (Rehri, Rendi, Arandi) ', 'Melon', 'Cashew', 'Drum Stick',
#        'Duck', 'Sorghum (Jowar/Great Millet)',
#        'Horse Gram (kulthi/kultha)', 'Crossandra', 'Turmeric',
#        'Coriander', 'Hibiscus (Gurhal)', 'Mint', 'Soybean (bhat)',
#        'Mosambi', 'Cowpea (Vegetable)', 'Jasmine',
# ...

# %%
crops = ["Cotton (Kapas)", "Groundnut (pea nut/mung phalli)", "1137", 'Black Gram (urd bean)', 'Pigeon pea (red gram/arhar/tur)', 'Green Gram (Moong Bean/ Moong)', 'Chillies', 'Paddy (Dhan)']
df = df[df['Crop'].isin(crops)]
df
# Out:
#              StateName DistrictName        BlockName  Season        Sector  \
# 5       ANDHRA PRADESH       GUNTUR       AMARAVATHI     NaN   AGRICULTURE
# 17      ANDHRA PRADESH     ANANTPUR          RAPTADU     NaN   AGRICULTURE
# 26      ANDHRA PRADESH      KRISHNA    THOTLAVALLURU  KHARIF   AGRICULTURE
# 32      ANDHRA PRADESH  VIZIANAGARM      KOTHAVALASA     NaN   AGRICULTURE
# 33      ANDHRA PRADESH      KRISHNA  PENUGANCHIPROLU     NaN  HORTICULTURE
# ...                ...          ...              ...     ...           ...
# 161721  ANDHRA PRADESH     PRAKASAM          CHIRALA     NaN  HORTICULTURE
# 161722  ANDHRA PRADESH      KRISHNA  PENUGANCHIPROLU     NaN  HORTICULTURE
# 161725  ANDHRA PRADESH      KRISHNA       BANTUMILLI     NaN   AGRICULTURE
# 161729  ANDHRA PRADESH      KURNOOL          MIDTHUR     NaN   AGRICULTURE
# 161730  ANDHRA PRADESH      KRISHNA       AVANIGADDA     NaN   AGRICULTURE
#
#            Category                             Crop  \
# ...

# %%
cols = ['Crop', 'QueryType', 'QueryText', 'KccAns']
df = df[cols]
df['QueryType'].unique()
# Out:
# array(['Market Information', '\tPlant Protection\t',
#        'Nutrient Management', 'Weed Management',
#        'Seeds and Planting Material', 'Fertilizer Use and Availability',
#        'Varieties', 'Soil Testing', 'Agriculture Mechanization',
#        'Cultural Practices', 'Organic Farming', 'Seeds',
#        'Sowing Time and Weather', '\tField Preparation\t',
#        'Nursery Management', 'Bio-Pesticides and Bio-Fertilizers',
#        'Crop Insurance', 'Weather', 'Storage', 'Government Schemes',
#        'Vegetative Propagation and Tissue Culture',
#        'Post Harvest Preservation',
#        'Post Harvest Management (Cleaning, Grading, Packaging, Food Processing, Cool Chain etc.)',
#        '187', '184', '183', '\tWater Management\t', 'Field Preparation',
#        'Training and Exposure Visits', 'Power, Roads etc.', '0', 'Credit',
#        'Landscaping', 'Water Management, Micro Irrigation',
#        'Plasticulture', 'Medicinal and Aromatic Plants',
# ...

# %%
df.to_csv('test.csv')

# %%
cats = ['3', '10', '21', '22', 'Fertilizer Use and Availability', '\tPlant Protection\t', '76', '29', 'Weed Management', 'Bio-Pesticides and Bio-Fertilizers', 'Beekeeping']
df = df[df['QueryType'].isin(cats)]
final_dfs.append(df)

# %%
folder_path = "/home/dhatri/Capstone Project/KCC data/batch8/*.csv"
files = glob.glob(folder_path)
dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)
    
df = pd.concat(dfs, ignore_index=True)


df["Crop"].unique()
# Out:
# array(['Chillies', 'Mango', 'Black Gram (urd bean)', 'Sapota',
#        'Paddy (Dhan)', 'Others', 'Sesame (Gingelly/Til)/Sesamum',
#        'Groundnut (pea nut/mung phalli)', 'Onion', 'Tomato',
#        'Maize (Makka)', 'Citrus', 'Watermelon', 'Guava', 'Wheat',
#        'Ricebean', 'Kodo Millet (Kodara/Varagu)',
#        'Bengal Gram (Gram/Chick Pea/Kabuli/Chana)',
#        'Pigeon pea (red gram/arhar/tur)', 'Banana', 'Cotton (Kapas)',
#        'Ivy Gourd', 'Papaya', 'Cucumber', 'Musk Melon',
#        'Castor (Rehri, Rendi, Arandi) ', 'French Bean',
#        'Green Gram (Moong Bean/ Moong)', 'Sorghum (Jowar/Great Millet)',
#        'Dog', 'Cauliflower', 'Brinjal', 'Passion Fruit', 'Cluster Bean',
#        'Pumpkin', 'Bhindi(Okra/Ladysfinger)',
#        'Little Millet (Samai/Kutki/kodo-kutki)', 'Beans ', 'Cashew',
#        'Italian Millet (Thenai/Navane/Foxtail Millet/Kang)', 'Drum Stick',
#        'Ridge Gourd', 'Marigold', 'Pomegranate', 'Napier Grass', 'Carrot',
# ...

# %%
crops = ["Cotton (Kapas)", "Groundnut (pea nut/mung phalli)", "1137", 'Black Gram (urd bean)', 'Pigeon pea (red gram/arhar/tur)', 'Green Gram (Moong Bean/ Moong)', 'Chillies', 'Paddy (Dhan)']
df = df[df['Crop'].isin(crops)]
df
# Out:
#              StateName   DistrictName    BlockName Season        Sector  \
# 0       ANDHRA PRADESH        NELLORE   SULLURPETA    NaN  HORTICULTURE
# 2       ANDHRA PRADESH       PRAKASAM     KOMAROLU    NaN   AGRICULTURE
# 4       ANDHRA PRADESH        NELLORE    SYDAPURAM    NaN   AGRICULTURE
# 10      ANDHRA PRADESH       PRAKASAM        DARSI    NaN  HORTICULTURE
# 11      ANDHRA PRADESH        NELLORE     PELLAKUR    NaN   AGRICULTURE
# ...                ...            ...          ...    ...           ...
# 206024  ANDHRA PRADESH        KRISHNA    A.KONDURU    NaN   AGRICULTURE
# 206025  ANDHRA PRADESH  EAST GODAVARI   PEDDAPURAM    NaN   AGRICULTURE
# 206026  ANDHRA PRADESH         GUNTUR  BELLAMKONDA    NaN   AGRICULTURE
# 206042  ANDHRA PRADESH  EAST GODAVARI         0       NaN   AGRICULTURE
# 206044  ANDHRA PRADESH       CHITTOOR  B.KOTHAKOTA    NaN   AGRICULTURE
#
#            Category                             Crop  \
# ...

# %%
cols = ['Crop', 'QueryType', 'QueryText', 'KccAns']
df = df[cols]
df['QueryType'].unique()
# Out:
# array(['Nutrient Management', 'Sowing Time and Weather',
#        '\tPlant Protection\t', 'Fertilizer Use and Availability',
#        'Varieties', 'Weed Management', 'Seeds',
#        'Agriculture Mechanization', 'Market Information', 'Weather',
#        '\tField Preparation\t', '\tWater Management\t',
#        'Water Management, Micro Irrigation', 'Cultural Practices',
#        'Vegetative Propagation and Tissue Culture', 'Credit',
#        'Training and Exposure Visits', 'Storage', 'Government Schemes',
#        'Plasticulture', 'Landscaping', 'Power, Roads etc.',
#        'Seeds and Planting Material', 'Organic Farming',
#        'Bio-Pesticides and Bio-Fertilizers', 'Nursery Management',
#        'Soil Testing', '0', 'Field Preparation', 'Soil Health Card',
#        'Crop Insurance', 'Post Harvest Preservation', 'Cold Storage',
#        'Spices and Condiment Crops', 'Medicinal and Aromatic Plants',
# ...

# %%
df.to_csv('test.csv')

# %%
cats = ['3', '10', '21', '22', 'Fertilizer Use and Availability', '\tPlant Protection\t', '76', '29', 'Weed Management', 'Bio-Pesticides and Bio-Fertilizers', 'Beekeeping']
df = df[df['QueryType'].isin(cats)]
final_dfs.append(df)

# %%
folder_path = "/home/dhatri/Capstone Project/KCC data/batch9/*.csv"
files = glob.glob(folder_path)
dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)
    
df = pd.concat(dfs, ignore_index=True)

# %%
df["Crop"].unique()
# Out:
# array(['Cotton (Kapas)', 'Chillies', 'Mango', 'Sunflower (suryamukhi)',
#        'Pigeon pea (red gram/arhar/tur)', 'Paddy (Dhan)',
#        'Groundnut (pea nut/mung phalli)', 'Others', 'Papaya',
#        'Maize (Makka)', 'Black Gram (urd bean)', 'Tomato',
#        'Sesame (Gingelly/Til)/Sesamum',
#        'Bengal Gram (Gram/Chick Pea/Kabuli/Chana)', 'Curry Leaf',
#        'Chrysanthemum', 'Sorghum (Jowar/Great Millet)',
#        'Castor (Rehri, Rendi, Arandi) ', 'Betel Vine', 'Guava', 'Brinjal',
#        'Indian rapeseed and mustard (yellow sarson)', 'Lemon', 'Citrus',
#        'Italian Millet (Thenai/Navane/Foxtail Millet/Kang)',
#        'Bitter Gourd', 'Radish', 'Horse Gram (kulthi/kultha)', 'Wheat',
#        'Bhindi(Okra/Ladysfinger)', 'Watermelon', 'Mosambi', 'Coconut',
#        'Pearl Millet (Bajra/Bulrush Millet/Spiked Millet)', 'Marigold',
#        'Cucumber', 'Linseed (alsi)', 'Goat', 'Broad Bean', 'Triticale',
# ...

# %%
crops = ["Cotton (Kapas)", "Groundnut (pea nut/mung phalli)", "1137", 'Black Gram (urd bean)', 'Pigeon pea (red gram/arhar/tur)', 'Green Gram (Moong Bean/ Moong)', 'Chillies', 'Paddy (Dhan)']
df = df[df['Crop'].isin(crops)]
df
# Out:
#              StateName   DistrictName                BlockName  Season  \
# 0       ANDHRA PRADESH         Y S R                 MYLAVARAM     NaN
# 1       ANDHRA PRADESH         GUNTUR                VELDURTHY     NaN
# 2       ANDHRA PRADESH         GUNTUR            PHIRANGIPURAM     NaN
# 5       ANDHRA PRADESH        KURNOOL                  TUGGALI     NaN
# 6       ANDHRA PRADESH  WEST GODAVARI               THALLAPUDI     NaN
# ...                ...            ...                      ...     ...
# 199487  ANDHRA PRADESH       PRAKASAM                  PARCHUR     NaN
# 199498  ANDHRA PRADESH        KURNOOL  DHONE ALIAS DRONACHALAM     NaN
# 199499  ANDHRA PRADESH     SRIKAKULAM                   LAVERU     NaN
# 199500  ANDHRA PRADESH       ANANTPUR               BOMMANAHAL     NaN
# 199501  ANDHRA PRADESH        KURNOOL  DHONE ALIAS DRONACHALAM     NaN
#
#               Sector     Category                             Crop  \
# ...

# %%
cols = ['Crop', 'QueryType', 'QueryText', 'KccAns']
df = df[cols]
df['QueryType'].unique()
# Out:
# array(['\tPlant Protection\t', 'Market Information', 'Weather',
#        'Nutrient Management', 'Varieties', 'Seeds', 'Cultural Practices',
#        'Fertilizer Use and Availability', 'Weed Management', 'Credit',
#        'Sowing Time and Weather', 'Government Schemes', 'Crop Insurance',
#        '\tWater Management\t', 'Bio-Pesticides and Bio-Fertilizers',
#        'Seeds and Planting Material',
#        'Water Management, Micro Irrigation', 'Post Harvest Preservation',
#        'Vegetative Propagation and Tissue Culture', 'Organic Farming',
#        'Field Preparation', 'Soil Testing', '0', 'Soil Health Card',
#        'Agriculture Mechanization', 'Nursery Management',
#        '\tField Preparation\t', 'Training and Exposure Visits', 'Storage',
#        'Post Harvest Management (Cleaning, Grading, Packaging, Food Processing, Cool Chain etc.)',
#        'Spices and Condiment Crops', 'Power, Roads etc.', 'Floriculture',
#        'Cold Storage', 'Plasticulture'], dtype=object)

# %%
df.to_csv('test.csv')

# %%
cats = ['3', '10', '21', '22', 'Fertilizer Use and Availability', '\tPlant Protection\t', '76', '29', 'Weed Management', 'Bio-Pesticides and Bio-Fertilizers', 'Beekeeping']
df = df[df['QueryType'].isin(cats)]
final_dfs.append(df)

# %%
folder_path = "/home/dhatri/Capstone Project/KCC data/batch10/*.csv"
files = glob.glob(folder_path)
dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)
    
df = pd.concat(dfs, ignore_index=True)


df["Crop"].unique()
# Out:
# array(['Cotton (Kapas)', 'Brinjal', 'Paddy (Dhan)',
#        'Sugarcane (Noble Cane)', 'Others', 'Maize (Makka)', 'Carrot',
#        'Black Gram (urd bean)', 'Chillies',
#        'FingerMillet  (Ragi/Mandika)', 'Ridge Gourd',
#        'Sesame (Gingelly/Til)/Sesamum', 'Oil palm', 'Lilliums',
#        'Drum Stick', 'Bhindi(Okra/Ladysfinger)', 'Onion', 'Cabbage',
#        'Green Gram (Moong Bean/ Moong)', 'Papaya', 'Mango',
#        'Bottle Gourd ', 'Coconut', 'Tomato', 'Capsicum', 'Cucumber',
#        'Aonla', 'Bitter Gourd', 'Citrus', 'Cowpea (Vegetable)',
#        'Groundnut (pea nut/mung phalli)', 'Cluster Bean', 'China Astor',
#        'Cauliflower', 'Spine Gourd', 'Coriander', 'Tumba', 'Guava',
#        'Ribbed Gourd (Kali Tori)', 'Orange', 'fodder maize ',
#        'Roselle (Mesta)', 'Ber', 'Lettuce', 'Watermelon',
#        'Pigeon pea (red gram/arhar/tur)', '0', 'Dolichos Bean', 'Banana',
#        'Mosambi', 'Sorghum (Jowar/Great Millet)', 'POULTRY  FARM ',
# ...

# %%
crops = ["Cotton (Kapas)", "Groundnut (pea nut/mung phalli)", "1137", 'Black Gram (urd bean)', 'Pigeon pea (red gram/arhar/tur)', 'Green Gram (Moong Bean/ Moong)', 'Chillies', 'Paddy (Dhan)']
df = df[df['Crop'].isin(crops)]
df
# Out:
#              StateName      DistrictName       BlockName  Season  \
# 0            TELANGANA          ADILABAD        BHEEMPUR     NaN
# 2            TELANGANA  RAJANNA SIRCILLA   ILLANTHAKUNTA     NaN
# 9            TELANGANA             MEDAK       KULCHARAM     NaN
# 10           TELANGANA        WANAPARTHY          PANGAL     NaN
# 12           TELANGANA          WARANGAL        WARANGAL     NaN
# ...                ...               ...             ...     ...
# 173716  ANDHRA PRADESH            Y S R          B KODUR     NaN
# 173720  ANDHRA PRADESH           KRISHNA  KANCHIKACHERLA     NaN
# 173724  ANDHRA PRADESH            GUNTUR       ATCHEMPET     NaN
# 173727  ANDHRA PRADESH           KURNOOL         TUGGALI     NaN
# 173728  ANDHRA PRADESH          PRAKASAM         PARCHUR     NaN
#
#               Sector     Category                             Crop  \
# 0        AGRICULTURE  Fiber Crops                   Cotton (Kapas)
# ...

# %%
cols = ['Crop', 'QueryType', 'QueryText', 'KccAns']
df = df[cols]
df['QueryType'].unique()
# Out:
# array(['Market Information', '\tPlant Protection\t',
#        'Nutrient Management', 'Weed Management',
#        'Fertilizer Use and Availability', 'Cultural Practices', 'Weather',
#        'Government Schemes', 'Sowing Time and Weather', 'Varieties',
#        'Seeds', '\tField Preparation\t', 'Post Harvest Preservation',
#        'Storage', 'Vegetative Propagation and Tissue Culture',
#        '\tWater Management\t', 'Seeds and Planting Material', 'Credit',
#        'Crop Insurance', 'Soil Health Card', 'Agriculture Mechanization',
#        'Nursery Management', 'Soil Testing',
#        'Bio-Pesticides and Bio-Fertilizers', 'Organic Farming',
#        'Training and Exposure Visits', 'Field Preparation',
#        'Water Management, Micro Irrigation', 'Power, Roads etc.',
#        'Spices and Condiment Crops',
#        'Post Harvest Management (Cleaning, Grading, Packaging, Food Processing, Cool Chain etc.)',
#        '0', 'Plasticulture'], dtype=object)

# %%
df.to_csv('test.csv')

# %%
cats = ['3', '10', '21', '22', 'Fertilizer Use and Availability', '\tPlant Protection\t', '76', '29', 'Weed Management', 'Bio-Pesticides and Bio-Fertilizers', 'Beekeeping']
df = df[df['QueryType'].isin(cats)]
final_dfs.append(df)

# %%
folder_path = "/home/dhatri/Capstone Project/KCC data/batch11/*.csv"
files = glob.glob(folder_path)
dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)
    
df = pd.concat(dfs, ignore_index=True)


df["Crop"].unique()
# Out:
# array(['Others', 'Paddy (Dhan)', 'Tomato', 'Cotton (Kapas)',
#        'Soybean (bhat)', 'Chillies', 'Maize (Makka)',
#        'Sesame (Gingelly/Til)/Sesamum', 'Turmeric', 'Sunnhemp (Patua)',
#        'Brinjal', '0', 'Pillipesara', 'Pigeon pea (red gram/arhar/tur)',
#        'Citrus', 'Faba Bean (Horse Bean/windsor Bean)', 'Cluster Bean',
#        'Sorghum (Jowar/Great Millet)', 'Cowpea (Vegetable)', 'Dhaincha',
#        'Oil palm', 'Ridge Gourd', 'Onion', 'Mustard', 'Mango',
#        'Green Gram (Moong Bean/ Moong)', 'Bitter Gourd', 'Garlic',
#        'Black Gram (urd bean)', 'Mosambi', 'Bhindi(Okra/Ladysfinger)',
#        'Ribbed Gourd (Kali Tori)', 'Eculeptous', 'Mint', 'Cucumber',
#        'Papaya', 'Methi (Fenugreek)', 'Fig', 'Litchi', 'Guava',
#        'Groundnut (pea nut/mung phalli)', 'Sandal Wood', 'Drum Stick',
#        'Ginger', 'Pumpkin', 'Coconut', 'Ivy Gourd', 'Lemon', 'Cinnamon',
#        'Pearl Millet (Bajra/Bulrush Millet/Spiked Millet)', 'Cauliflower',
# ...

# %%
crops = ["Cotton (Kapas)", "Groundnut (pea nut/mung phalli)", "1137", 'Black Gram (urd bean)', 'Pigeon pea (red gram/arhar/tur)', 'Green Gram (Moong Bean/ Moong)', 'Chillies', 'Paddy (Dhan)']
df = df[df['Crop'].isin(crops)]
df
# Out:
#              StateName DistrictName        BlockName  Season       Sector  \
# 11           TELANGANA        MEDAK      MANOHARABAD     NaN  AGRICULTURE
# 14           TELANGANA        MEDAK       KOWDIPALLI     NaN  AGRICULTURE
# 18           TELANGANA        MEDAK        KULCHARAM     NaN  AGRICULTURE
# 33           TELANGANA        MEDAK        KULCHARAM     NaN  AGRICULTURE
# 34           TELANGANA        MEDAK         ALLADURG     NaN  AGRICULTURE
# ...                ...          ...              ...     ...          ...
# 158270  ANDHRA PRADESH      KRISHNA     JAGGAYYAPETA     NaN  AGRICULTURE
# 158274  ANDHRA PRADESH      KRISHNA     JAGGAYYAPETA     NaN  AGRICULTURE
# 158276  ANDHRA PRADESH      KRISHNA       REDDIGUDEM     NaN  AGRICULTURE
# 158278  ANDHRA PRADESH      KRISHNA        A.KONDURU     NaN  AGRICULTURE
# 158300  ANDHRA PRADESH      KRISHNA  PENUGANCHIPROLU     NaN  AGRICULTURE
#
#            Category            Crop             QueryType  \
# ...

# %%
cols = ['Crop', 'QueryType', 'QueryText', 'KccAns']
df = df[cols]
df['QueryType'].unique()
# Out:
# array(['Seeds', 'Varieties', 'Government Schemes', 'Weather',
#        'Cultural Practices', 'Nutrient Management', 'Weed Management',
#        '\tPlant Protection\t', 'Sowing Time and Weather',
#        'Fertilizer Use and Availability', 'Market Information',
#        'Nursery Management', '\tWater Management\t',
#        'Training and Exposure Visits', 'Seeds and Planting Material',
#        'Storage', 'Bio-Pesticides and Bio-Fertilizers', 'Soil Testing',
#        'Organic Farming', 'Agriculture Mechanization', 'Credit',
#        'Power, Roads etc.', 'Crop Insurance', 'Soil Health Card',
#        '\tField Preparation\t', 'Post Harvest Preservation',
#        'Vegetative Propagation and Tissue Culture', 'Field Preparation',
#        'Water Management, Micro Irrigation',
#        'Post Harvest Management (Cleaning, Grading, Packaging, Food Processing, Cool Chain etc.)',
#        'Plasticulture', 'Old/Senile Orchard Rejuvenation'], dtype=object)

# %%
df.to_csv('test.csv')

# %%
cats = ['3', '10', '21', '22', 'Fertilizer Use and Availability', '\tPlant Protection\t', '76', '29', 'Weed Management', 'Bio-Pesticides and Bio-Fertilizers', 'Beekeeping']
df = df[df['QueryType'].isin(cats)]
final_dfs.append(df)

# %%
folder_path = "/home/dhatri/Capstone Project/KCC data/batch12/*.csv"
files = glob.glob(folder_path)
dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)
    
df = pd.concat(dfs, ignore_index=True)
df["Crop"].unique()
# Out:
# array(['Maize (Makka)', 'Groundnut (pea nut/mung phalli)',
#        'Cotton (Kapas)', 'Pigeon pea (red gram/arhar/tur)', 'Others',
#        'Chillies', 'Tomato', 'Horse Gram (kulthi/kultha)', 'Paddy (Dhan)',
#        'Bengal Gram (Gram/Chick Pea/Kabuli/Chana)',
#        'Sorghum (Jowar/Great Millet)', 'Pomegranate',
#        'Bovine(Cow,Buffalo)', 'Green Gram (Moong Bean/ Moong)',
#        'Buffel Grass (Anjan Grass)', 'Black Gram (urd bean)', 'Ber',
#        'Banana', 'Onion', 'Mango', 'Acid Lime', 'Citrus',
#        'Italian Millet (Thenai/Navane/Foxtail Millet/Kang)',
#        'Chrysanthemum', 'Aonla', 'Brinjal', 'Grape',
#        'Castor (Rehri, Rendi, Arandi) ', 'Tobacco', 'Cluster Bean',
#        'Drum Stick', 'Beans ',
#        'Pearl Millet (Bajra/Bulrush Millet/Spiked Millet)',
#        'Sesame (Gingelly/Til)/Sesamum', 'Cumin', 'Potato',
#        'BAJRA NAPIER HYBRID', 'Ridge Gourd', 'Cabbage', 'Mushroom',
#        'Bitter Gourd', 'Winged Bean', 'Marigold', 'Mosambi',
# ...

# %%
crops = ["Cotton (Kapas)", "Groundnut (pea nut/mung phalli)", "1137", 'Black Gram (urd bean)', 'Pigeon pea (red gram/arhar/tur)', 'Green Gram (Moong Bean/ Moong)', 'Chillies', 'Paddy (Dhan)']
df = df[df['Crop'].isin(crops)]
df
# Out:
#             StateName DistrictName      BlockName  Season        Sector  \
# 1      ANDHRA PRADESH     ANANTPUR         PAMIDI     NaN   AGRICULTURE
# 2      ANDHRA PRADESH     ANANTPUR    PEDDAPAPPUR     NaN   AGRICULTURE
# 4      ANDHRA PRADESH     ANANTPUR       GUNTAKAL     NaN   AGRICULTURE
# 6      ANDHRA PRADESH     ANANTPUR         KUDAIR     NaN  HORTICULTURE
# 7      ANDHRA PRADESH     ANANTPUR          GOOTY     NaN   AGRICULTURE
# ...               ...          ...            ...     ...           ...
# 78408  ANDHRA PRADESH      KURNOOL   KOLIMIGUNDLA     NaN   AGRICULTURE
# 78413  ANDHRA PRADESH      KURNOOL        TUGGALI     NaN   AGRICULTURE
# 78419  ANDHRA PRADESH       Y S R     PORUMAMILLA     NaN   AGRICULTURE
# 78423  ANDHRA PRADESH       Y S R   JAMMALAMADUGU     NaN   AGRICULTURE
# 78425  ANDHRA PRADESH  VIZIANAGARM        MAKKUVA     NaN   AGRICULTURE
#
#           Category                             Crop  \
# ...

# %%
cols = ['Crop', 'QueryType', 'QueryText', 'KccAns']
df = df[cols]
df['QueryType'].unique()
# Out:
# array(['Post Harvest Preservation', '\tPlant Protection\t',
#        'Nutrient Management', 'Weather', '\tWater Management\t',
#        'Soil Health Card', 'Cultural Practices', 'Market Information',
#        'Sowing Time and Weather', 'Weed Management',
#        'Water Management, Micro Irrigation', 'Government Schemes',
#        'Fertilizer Use and Availability', 'Seeds', 'Varieties',
#        'Power, Roads etc.', 'Organic Farming',
#        'Training and Exposure Visits', 'Agriculture Mechanization',
#        'Seeds and Planting Material', '\tField Preparation\t',
#        'Soil Testing', 'Vegetative Propagation and Tissue Culture',
#        'Nursery Management',
#        'Post Harvest Management (Cleaning, Grading, Packaging, Food Processing, Cool Chain etc.)',
#        'Credit', 'Storage', 'Spices and Condiment Crops',
#        'Crop Insurance', 'Bio-Pesticides and Bio-Fertilizers',
#        'Field Preparation', 'Plasticulture'], dtype=object)

# %%
df.to_csv('test.csv')

# %%
cats = ['3', '10', '21', '22', 'Fertilizer Use and Availability', '\tPlant Protection\t', '76', '29', 'Weed Management', 'Bio-Pesticides and Bio-Fertilizers', 'Beekeeping']
df = df[df['QueryType'].isin(cats)]
final_dfs.append(df)

# %%
final_dfs
# Out:
# [      Crop QueryType                                       QueryText  \
#  13    1137         3          ASKED ABOUT THE CONTROL OF BPH IN RICE
#  15    1137         3  ASKED ABOUT THE CONTROL OF LEAF FOLDER IN RICE
#  33    1137         3        ASKED ABOUT THE CONTROL OF HISPA IN RICE
#  37    1137         3        ASKED ABOUT THE CONTROL OF BLAST IN RICE
#  45    1137        21        ASKED ABOUT THE CONTROL OF WEEDS IN RICE
#  ...    ...       ...                                             ...
#  8027  1137         3              ASKED ABOUT CONTROL OF BPH IN RICE
#  8036  1137         3            ASSKED ABOUT CONTROL RICE STEM BORER
#  8041  1137         3  ASKED ABOUT CONTROL FOR RICE STEM BORER DAMAGE
#  8049  1137         3              ASKED ABOUT CONTROL OF BPH IN RICE
#  8079  1137         3  ASKED ABOUT CONTROL FOR RICE STEM BORER DAMAGE
#
#                                               KccAns
#  13           RECOMMENDED TO SPRAY ACEPHATE 1.5GM/LT
# ...

# %%
final_df = pd.concat(final_dfs, ignore_index=True)

# %%
final_df
# Out:
#                                    Crop                        QueryType  \
# 0                                  1137                                3
# 1                                  1137                                3
# 2                                  1137                                3
# 3                                  1137                                3
# 4                                  1137                               21
# ...                                 ...                              ...
# 333823                     Paddy (Dhan)             \tPlant Protection\t
# 333824  Groundnut (pea nut/mung phalli)             \tPlant Protection\t
# 333825            Black Gram (urd bean)                  Weed Management
# 333826                     Paddy (Dhan)  Fertilizer Use and Availability
# 333827                     Paddy (Dhan)             \tPlant Protection\t
#
#                                                 QueryText  \
# ...

# %%
final_df.drop('QueryType', inplace=True, axis=1)

# %%
final_df
# Out:
#                                    Crop  \
# 0                                  1137
# 1                                  1137
# 2                                  1137
# 3                                  1137
# 4                                  1137
# ...                                 ...
# 333823                     Paddy (Dhan)
# 333824  Groundnut (pea nut/mung phalli)
# 333825            Black Gram (urd bean)
# 333826                     Paddy (Dhan)
# 333827                     Paddy (Dhan)
#
#                                                 QueryText  \
# 0                  ASKED ABOUT THE CONTROL OF BPH IN RICE
# 1          ASKED ABOUT THE CONTROL OF LEAF FOLDER IN RICE
# 2                ASKED ABOUT THE CONTROL OF HISPA IN RICE
# 3                ASKED ABOUT THE CONTROL OF BLAST IN RICE
# 4                ASKED ABOUT THE CONTROL OF WEEDS IN RICE
# ...                                                   ...
# 333823  Galileo Way Picoxystrobin 7.05% + Propiconazol...
# ...

# %%
final_df['Crop'] = final_df['Crop'].replace('1137', "Paddy (Dhan)")

# %%
final_df
# Out:
#                                    Crop  \
# 0                          Paddy (Dhan)
# 1                          Paddy (Dhan)
# 2                          Paddy (Dhan)
# 3                          Paddy (Dhan)
# 4                          Paddy (Dhan)
# ...                                 ...
# 333823                     Paddy (Dhan)
# 333824  Groundnut (pea nut/mung phalli)
# 333825            Black Gram (urd bean)
# 333826                     Paddy (Dhan)
# 333827                     Paddy (Dhan)
#
#                                                 QueryText  \
# 0                  ASKED ABOUT THE CONTROL OF BPH IN RICE
# 1          ASKED ABOUT THE CONTROL OF LEAF FOLDER IN RICE
# 2                ASKED ABOUT THE CONTROL OF HISPA IN RICE
# 3                ASKED ABOUT THE CONTROL OF BLAST IN RICE
# 4                ASKED ABOUT THE CONTROL OF WEEDS IN RICE
# ...                                                   ...
# 333823  Galileo Way Picoxystrobin 7.05% + Propiconazol...
# ...

# %%
final_df = final_df.drop_duplicates(subset=['QueryText'], keep='first')

# %%
final_df
# Out:
#                          Crop  \
# 0                Paddy (Dhan)
# 1                Paddy (Dhan)
# 2                Paddy (Dhan)
# 3                Paddy (Dhan)
# 4                Paddy (Dhan)
# ...                       ...
# 333821           Paddy (Dhan)
# 333822           Paddy (Dhan)
# 333823           Paddy (Dhan)
# 333825  Black Gram (urd bean)
# 333826           Paddy (Dhan)
#
#                                                 QueryText  \
# 0                  ASKED ABOUT THE CONTROL OF BPH IN RICE
# 1          ASKED ABOUT THE CONTROL OF LEAF FOLDER IN RICE
# 2                ASKED ABOUT THE CONTROL OF HISPA IN RICE
# 3                ASKED ABOUT THE CONTROL OF BLAST IN RICE
# 4                ASKED ABOUT THE CONTROL OF WEEDS IN RICE
# ...                                                   ...
# 333821  farmer asked query on zinc deficiency manageme...
# 333822            PADDY  CROP (Validamycin 3% L) i USES ?
# 333823  Galileo Way Picoxystrobin 7.05% + Propiconazol...
# ...

# %%
final_df.to_csv("FINAL_DATASET_KCC_ENG.csv")
